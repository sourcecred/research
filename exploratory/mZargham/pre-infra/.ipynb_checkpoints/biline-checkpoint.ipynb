# %%
import numpy as np
import pandas as pd
import networkx as nx
import json
import os
import page_ranker as pr
import import_graph as ig
import inspect_subgraph as isg

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cwd = os.getcwd()

rel_path = "sample_graphs/sourcecred_sourcecred.json"
abs_file_path = os.path.abspath(os.path.join(cwd, '..', rel_path))

with open(abs_file_path) as json_file:  
    data = json.load(json_file)

# %%
G = ig.jsonToMultiDiGraph(data)

# %%
alpha = .1
iterations = 10

# %%
r, df, g = pr.pageRanker(G,alpha,iterations)

# %%
plt.hist(np.log10(r), bins = 15)
# Out:
# (array([2.918e+03, 1.654e+03, 2.600e+02, 1.300e+02, 6.430e+02, 2.160e+02,
#         8.500e+01, 1.700e+01, 5.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 3.000e+00]),
#  array([-4.02966898, -3.80308776, -3.57650655, -3.34992533, -3.12334411,
#         -2.8967629 , -2.67018168, -2.44360046, -2.21701924, -1.99043803,
#         -1.76385681, -1.53727559, -1.31069438, -1.08411316, -0.85753194,
#         -0.63095073]),
#  <a list of 15 Patch objects>)

# %%
df.apply(np.log10).plot(legend=False, figsize=(20,10))

# %%
top25 = list(df.T.reset_index().sort_values(iterations).tail(25).index)

# %%
isg.inspectSubGraph(G, top25, expand=False, verbose=False, label=True,pos = "kk")
