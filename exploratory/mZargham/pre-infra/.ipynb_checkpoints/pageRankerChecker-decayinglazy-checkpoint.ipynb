# %%
import numpy as np
import pandas as pd
import networkx as nx
import json
import os
import page_ranker as pr
import import_graph as ig
import inspect_subgraph as isg

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cwd = os.getcwd()

rel_path = "sample_graphs/sourcecred_sourcecred.json"
abs_file_path = os.path.abspath(os.path.join(cwd, '..', rel_path))

with open(abs_file_path) as json_file:  
    data = json.load(json_file)

# %%
G = ig.jsonToMultiDiGraph(data)

# %%
iterations = 20


alpha = 0
seed = {n:1/len(G.nodes) for n in G.nodes}
self_loop_wt = 1/1000

# %%
r, df, g = pr.pageRanker(G,
                         alpha,
                         iterations,
                         seed=seed,
                         initial_value = seed,
                         lazy=True,
                         self_loop_wt=self_loop_wt)

# %%
plt.hist(np.log10(r), bins = 15)
# Out:
# (array([2.000e+00, 2.000e+00, 1.000e+00, 4.700e+01, 2.445e+03, 1.343e+03,
#         9.840e+02, 6.180e+02, 4.680e+02, 1.800e+01, 1.000e+00, 0.000e+00,
#         0.000e+00, 2.000e+00, 1.000e+00]),
#  array([-6.59427556, -6.19614182, -5.79800808, -5.39987434, -5.0017406 ,
#         -4.60360686, -4.20547312, -3.80733938, -3.40920564, -3.0110719 ,
#         -2.61293816, -2.21480441, -1.81667067, -1.41853693, -1.02040319,
#         -0.62226945]),
#  <a list of 15 Patch objects>)

# %%
df.apply(np.log10).plot(legend=False, figsize=(20,10),alpha=.5)

# %%
top25 = list(df.T.reset_index().sort_values(iterations).tail(25).index)

# %%
isg.inspectSubGraph(G, top25, expand=False, verbose=False, label=True,pos = "kk")

# %%
df.sum(axis=1)
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    1.0
# 11    1.0
# 12    1.0
# 13    1.0
# 14    1.0
# 15    1.0
# 16    1.0
# 17    1.0
# 18    1.0
# 19    1.0
# 20    1.0
# dtype: float64

# %%
plt.hist([np.log10(v) for v in list(nx.get_node_attributes(G,'total_wt').values())])
# Out:
# (array([8.000e+00, 1.402e+03, 2.748e+03, 1.610e+03, 1.560e+02, 4.000e+00,
#         1.000e+00, 0.000e+00, 1.000e+00, 2.000e+00]),
#  array([-0.30016227,  0.07126248,  0.44268723,  0.81411198,  1.18553673,
#          1.55696148,  1.92838623,  2.29981098,  2.67123573,  3.04266048,
#          3.41408523]),
#  <a list of 10 Patch objects>)

# %%
r
# Out:
# array([1.07622914e-04, 1.15303351e-04, 1.06699045e-04, ...,
#        2.56176630e-05, 5.15151099e-02, 9.01537321e-04])
