# %%
import numpy as np
import pandas as pd
import networkx as nx
import json
import os
import page_ranker as pr
import import_graph as ig

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9b2e3b4647d3> in <module>
#       5 import os
#       6 import page_ranker as pr
# ----> 7 import import_graph as ig
#       8
#       9 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'import_graph'
